# %%
# Question: Count vowels in the string "Hello World"
text = "Hello World"
vowels = "aeiouAEIOU"
count = sum(1 for char in text if char in vowels)
print(f"String: {text}")
print(f"Number of vowels: {count}")
# Out:
# String: Hello World
# Number of vowels: 3

# %% [markdown]
# There are three ways

# %%
# Question 1: Reverse the string "Python Programming"
str=input("enter the string")
reversed_str=''
for char in str:
    reversed_str=char+reversed_str
print(reversed_str)
# Out:
# olleh

# %%
str=input("enter the string")
reversed_str=str[::-1]
print(reversed_str)
# Out:
# olleh

# %%
str=input("enter the string")
reversed_str="".join(reversed(str))
print(reversed_str)
# Out:
# olleh

# %%
# Question 2: Check if "racecar" is a palindrome
str=input("enter the string")
reversed_str=''
for char in str:
    reversed_str=char+reversed_str
print(reversed_str)
if reversed_str==str:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# racecar
# palindrome

# %%
# Question 3: Count the number of words in "Python is a great programming language"
str=input("enter the string")
split_word=str.split(" ")
count_word=len(split_word)
print(f"The number of words is {count_word}")
# Out:
# The number of words is 6

# %%
# Question 4: Convert "hello world" to title case
str=input("enter the string")
title_case=str.title()
print(title_case)
# Out:
# Hello World

# %%
# Question 5: Find the length of string "Data Science"
str=input("enter the string")
length_of=len(str)
print(length_of)
# Out:
# 12

# %%
# Question 6: Replace all spaces with underscores in "Machine Learning"

str=input("enter the string")
replaceing_space=str.replace(" ","_")
print(replaceing_space)
# Out:
# Machine_Learning

# %%
# Question 7: Check if "python" is in "Python Programming Language"
str1=input("enter the string")
str2=input("enter the string")
if str2 in str1:
    print("The string two is present in string one")
else:
    print("The String 2 is not present in string 1")
# Out:
# The string two is present in string one

# %%
# Question 8: Extract the first 5 characters from "Artificial Intelligence"
str1=input("enter the string")
first_5_char=str1[:5]
print(first_5_char)
# Out:
# Artif

# %%
# Question 9: Convert "UPPERCASE" to lowercase
str1=input("enter the string")
lower_letter=str1.lower()
print(lower_letter)
# Out:
# hi this navya from sonaganahalli

# %%
# Question 10: Remove all vowels from "Computer Science"
str1=input("enter the string")
vowel='aeiouAEIOU'
removed_vowels=''
for i in str1:
    if i not in vowel:
        removed_vowels+=i
print(removed_vowels)
# Out:
# Cmptr Scnc
